# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import logging
# from sklearn.preprocessing import StandardScaler
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import confusion_matrix, classification_report
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import sys, os
# Setup logger for traceability
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

sys.path.append(os.path.abspath(os.path.join('..'))) 
from scripts.visualization import *
train_file_path = os.path.abspath(os.path.join('..', 'data', 'raw', 'train.csv'))
test_file_path = os.path.abspath(os.path.join('..', 'data', 'raw', 'test.csv'))

train_data = pd.read_csv(train_file_path)
test_data = pd.read_csv(test_file_path)


# Check the first few rows of the data
logger.info("Train Data Head:\n%s", train_data.head())
logger.info("Test Data Head:\n%s", test_data.head())
# Out:
# /tmp/ipykernel_25263/1327301600.py:11: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data = pd.read_csv(train_file_path)
# INFO:__main__:Train Data Head:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# INFO:__main__:Test Data Head:
#    Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4  2015-09-17   1.0      1            0              0
# ...

# %%
# Check the column names of the train and test datasets
logger.info("Train Data Columns: %s", train_data.columns)
logger.info("Test Data Columns: %s", test_data.columns)
# Out:
# INFO:__main__:Train Data Columns: Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')
# INFO:__main__:Test Data Columns: Index(['Id', 'Store', 'DayOfWeek', 'Date', 'Open', 'Promo', 'StateHoliday',
#        'SchoolHoliday'],
#       dtype='object')

# %%
# Run the function to plot the distributions
plot_sales_and_customers(logger=logger, train_data=train_data,test_data=test_data, plt=plt, sns=sns)

# %%
plot_promotions_distribution(logger=logger, train_data=train_data,test_data=test_data, plt=plt, sns=sns)
# Out:
# INFO:__main__:Plotting distribution of Promo...
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
analyze_holiday_sales(logger, train_data, plt, sns)
# Out:
# INFO:__main__:Analyzing sales behavior around holidays...
# ERROR:__main__:Error occurred during holiday sales analysis: functools.partial(<class 'matplotlib.lines.Line2D'>, xdata=[], ydata=[]) got multiple values for keyword argument 'label'

# %%
# Perform seasonal analysis
seasonal_behavior_analysis(logger, train_data, plt)
# Out:
# INFO:__main__:Analyzing seasonal purchase behaviors...
# INFO:__main__:Seasonal behavior analysis completed.

# %%
from scripts.salesPrediction import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from scripts.salesPrediction import *
#
# ModuleNotFoundError: No module named 'scripts'

# %%
X_train, y_train, X_test = prepare_features(train_data, test_data)

# %%
pipeline = build_pipeline()
trained_pipeline = train_and_evaluate(X_train, y_train, pipeline)

# %%
save_model(trained_pipeline)
